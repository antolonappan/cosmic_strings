# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import sys
sys.path.append("..")

# %%
# %load_ext autoreload
# %autoreload 2
import strings

# %%
l, cl = strings.compute_cls(G_mu=8.9*1e-4, P=1, N_k=10, l_max=500, progress_bar=False)
# Out:
# /Users/antoidicherianlonappan/Workspace/cosmic_strings/notebooks/../strings.py:71: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   inner, _ = quad(inner_integrand,

# %%
plt.plot(l, l**4 *cl*1e7, label=r'$G\mu = 8.9 \times 10^{-4}, P = 1$', color='blue', linewidth=1.5)
plt.title(r'Curl-mode Power Spectrum $\ell^4 C_\ell^{\varpi\varpi}$ vs. Multipole $\ell$', fontsize=14)
plt.xlabel(r'Multipole $\ell$', fontsize=12)
plt.ylabel(r'$\ell^4 C_\ell^{\varpi\varpi} \times 10^7 / 2\pi$', fontsize=12)
plt.ylim(0, 4)
plt.xlim(2, 500)
plt.xticks(np.arange(50, 501, 50))
plt.yticks(np.arange(0, 4.1, 1))
plt.legend(fontsize=9, loc='upper right')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.tight_layout()
